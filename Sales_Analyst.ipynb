# %% [markdown]
# # Sales Analysis

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Create dataframework from a CSV

# %%
df = pd.read_csv('super.csv',encoding = "ISO-8859-1")

# %% [markdown]
# ##### For more info about "ISO-8859-1" <https://docs.python.org/3/library/codecs.html#:~:text=The%20simplest%20text%20encoding%20(called,be%20encoded%20with%20this%20codec>

# %% [markdown]
# ##### In case to merge multiples files into a single CSV file

# %% [raw]
# df = pd.read_csv("./Sales_Data/Sales_April_2019.csv")
#
# filess [ file for file in os.listdir(* '/Sales_Data')]
#
# all_months_data = pd.DataFrame()
#
# for file in files:
#     df =pd.read_csv("./Sales_Data/"+file)
#     all_months_data = pd.concat([all_months_data, df])

# %% [markdown]
# ### Top 5 rows

# %%
df.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156   8/11/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   8/11/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688  12/06/2016  16/06/2016    Second Class    DV-13045
# 3  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
# 4  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### Clean up the data

# %% [markdown]
# #### Find NaN and drop rows

# %%
nan_df = df[df.isna().any(axis=1)]

nan_df.head()
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []

# %%
df = df.dropna(how='all')

df.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156   8/11/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   8/11/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688  12/06/2016  16/06/2016    Second Class    DV-13045
# 3  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
# 4  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# #### Find other types of errors

# %%
temp_df = df[df['Order ID'] == 'CA-2016-138688']

temp_df.head()
# Out:
#          Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 2  CA-2016-138688  12/06/2016  16/06/2016  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City       State  \
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name  Sales  Quantity  \
# 2  Self-Adhesive Address Labels for Typewriters b...  14.62         2
#
#    Discount  Profit
# 2       0.0  68.714

# %% [markdown]
# ### Add month column

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
##df['sales'] = df['sales'].astype(float)

df.head()
# Out:
#          Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-08-11  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156 2016-08-11  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688 2016-12-06  16/06/2016    Second Class    DV-13045
# 3  US-2015-108966 2015-11-10  18/10/2015  Standard Class    SO-20335
# 4  US-2015-108966 2015-11-10  18/10/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df['Month'] = df['Order Date'].dt.month

df.head()
# Out:
#          Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-08-11  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156 2016-08-11  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688 2016-12-06  16/06/2016    Second Class    DV-13045
# 3  US-2015-108966 2015-11-10  18/10/2015  Standard Class    SO-20335
# 4  US-2015-108966 2015-11-10  18/10/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    ...  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date                object
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                    object
# Quantity                  int64
# Discount                float64
# Profit                   object
# Month                     int64
# dtype: object

# %% [markdown]
# ### Question 1: What was the best month for sales?

# %%
df.groupby('Month').sum()['Discount']
# Out:
# C:\Users\ivanj\AppData\Local\Temp\ipykernel_24788\1538326807.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Month').sum()['Discount']
# Month
# 1      76.22
# 2      91.19
# 3     130.70
# 4     118.57
# 5     132.74
# 6     116.28
# 7     115.85
# 8     131.54
# 9     168.59
# 10    120.52
# 11    192.33
# 12    166.56
# Name: Discount, dtype: float64

# %%
#del df
